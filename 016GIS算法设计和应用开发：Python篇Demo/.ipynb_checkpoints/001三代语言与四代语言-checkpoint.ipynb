# %%
import random

# %%
ch = [chr(i) for i in range(97,123)]

# %%
name = ["{0}.{1}".format("".join(random.sample(ch,random.randint(3,5))),
                 "".join(random.sample(ch,random.randint(3,5)))) \
        for i in range(100000)]
name[:100]
# Out:
# ['yecv.msvu',
#  'wlicq.zxw',
#  'qiamc.wzdse',
#  'eiv.alpbr',
#  'cdsk.rbyk',
#  'zfcxr.wlbat',
#  'sfk.lones',
#  'ulyk.vcomu',
#  'cpes.ybgi',
#  'bjxm.elhw',
#  'ehvfz.xuioj',
#  'ktl.gnfs',
#  'mjqwn.yjn',
#  'quhr.stfby',
#  'ehinm.pxbe',
#  'moixu.aupm',
#  'jowp.mhv',
#  'jzab.lesir',
#  'weqvr.ljrgx',
#  'gcpo.zxuh',
#  'jgqr.bmr',
#  'nmqk.ehda',
#  'ptrqo.cbje',
#  'scbgo.mxil',
#  'ebs.foaq',
#  'ubk.pnx',
#  'wjei.hqgpc',
#  'aylu.opdk',
#  'jhktm.kqi',
#  'jexr.aerou',
#  'cvy.fih',
#  'sbi.hxgti',
#  'bvt.rkh',
#  'zxnod.bahyj',
#  'gqnvx.bfcu',
#  'lsc.kqth',
#  'kbu.xkycq',
#  'rlxha.kvsfy',
#  'ikg.vjrk',
#  'qpty.oxa',
#  'gcj.qrcp',
#  'uxa.snr',
#  'mbvs.xydf',
#  'lpyv.gxuq',
#  'yriac.zpm',
#  'bcfho.xnyv',
#  'zyslm.ykq',
#  'ctv.mpfqb',
#  'etjm.khfnm',
#  'uoqpe.rgoq',
#  'ebny.ldh',
#  'smg.ouvp',
#  'nvug.fvznc',
#  'xjhkw.apmgj',
#  'xor.hwr',
#  'liz.atuo',
#  'zejqi.meir',
#  'wmk.jctz',
#  'ryn.dbeis',
#  'avncg.qtghc',
#  'jyxzn.yfk',
#  'rjwyv.kwx',
#  'yskc.cksef',
#  'ohc.aurv',
#  'cdfxg.fpnb',
#  'vhxl.jtbl',
#  'juce.euori',
#  'hvuxd.wmna',
#  'nxy.ydx',
#  'xvdgb.yxcaw',
#  'pec.zdvm',
#  'pafvk.trbhi',
#  'ibwo.mvtr',
#  'rydta.qxp',
#  'upwt.yxriw',
#  'kmf.gbm',
#  'cfltm.vaqmh',
#  'asjzk.cyk',
#  'hmes.xmvr',
#  'ofhw.wbnl',
#  'aqij.piza',
#  'wsavh.qmh',
#  'dxk.onmgi',
#  'nuz.ikont',
#  'fgx.vir',
#  'vgduz.ecg',
#  'duxv.mns',
#  'lfnwp.lqkev',
#  'xtih.tgc',
#  'cms.nkxi',
#  'kge.kptzx',
#  'rpqc.tyqwz',
#  'mwuzr.twdc',
#  'nkbjo.jdta',
#  'klsvw.rik',
#  'ucjq.hwp',
#  'ftsi.fowns',
#  'rda.iwzq',
#  'ycrbk.yiehr',
#  'uotfg.mjtg']

# %%
age = [random.randint(25,58) for i in range(100000)]

# %% [markdown]
# ### 筛选出name中包含ab的员工

# %%
index = []
for i in range(len(name)):
    if name[i].find("ab") > -1:
        index.append(i)

# %%
len(index)
# Out:
# 908

# %%
for i in index:
    print(name[i])
# Out:
# jzab.lesir
# abvue.htu
# whts.oabd
# qhsuj.zwmab
# wruv.qfab
# revuy.abnw
# ixf.vab
# zoab.znja
# abniq.jhtr
# wjabk.ibd
# ldj.dab
# ablv.jcqv
# iurab.dvuz
# gme.abto
# fnqab.weu
# ypj.qab
# usgkh.abik
# ybi.abznw
# dwaby.zcxkt
# acgqd.abxfz
# wyq.hoabf
# amlo.abko
# orgsm.qabrk
# nemf.abjn
# oleab.bfxgj
# hbaug.abes
# cjx.yabsh
# fab.niulg
# jxwyt.iabn
# abl.iearx
# bnvl.mabn
# zjh.tab
# pxaro.abzx
# oyr.wkab
# abxe.oql
# nhaby.qjiz
# btspk.abk
# ikwzf.lab
# pabi.myob
# qab.zji
# fve.lab
# esqy.ruab
# epjhn.tpab
# oab.zhtsm
# diabq.lswqf
# yabu.buh
# abujs.vcbsi
# kmabp.zuhro
# dab.oyzk
# dabvr.jzwc
# goab.bhkm
# ehlqc.iuab
# qab.kobz
# eabro.vpans
# wjab.lhi
# uvab.qogyp
# ielab.nfvgh
# gzabq.oqxr
# rabnt.pvr
# npqyx.abj
# hruxa.pab
# yrx.tab
# ytwr.kablo
# slxc.abci
# ghxo.hktab
# abc.zai
# qvxlg.hsab
# dnwfz.fabvj
# qnxr.gab
# abj.dfne
# lypnc.taby
# ablco.runw
# phxz.oabeu
# uegj.vabk
# uabfk.cndgy
# pibkr.tabvy
# abus.lhemr
# abgv.qyp
# lab.yfztn
# zknab.phl
# abw.tblm
# ntqf.iuabo
# jab.glfz
# kmpo.abs
# qkyab.lvwp
# fxpmn.abzqg
# iurv.abd
# jlo.gabsp
# rqg.abqdr
# nofpq.klpab
# vab.fhat
# aburf.zsyf
# iqdn.xnabm
# unq.abd
# evnjo.eab
# gabzr.sqr
# hvak.miabf
# aofli.iabvk
# kwf.ynfab
# qsayo.jpabl
# abhmv.nabzs
# rob.jabtg
# trsyg.lab
# gab.xoka
# tgoje.abr
# avnei.xezab
# abc.qcwuk
# tlcfu.rfabg
# qayhg.abpf
# rzc.eabn
# jabch.qfng
# abnxy.atpsl
# mnb.wizab
# cmab.vpug
# gjy.sabz
# zopn.abml
# kwabf.dkgqm
# iczds.abe
# fkmi.abv
# nig.abry
# zgab.pwucq
# hzabd.tixwm
# runab.mxt
# fuogl.gabt
# ydk.sgwab
# abndx.kmvau
# hab.slnu
# abnev.vmleg
# msbf.abje
# vyab.mhc
# jmfn.abf
# kfyo.abxo
# abmv.zyi
# abf.tiagp
# eqck.abh
# esu.nogab
# wkv.abl
# maw.dabo
# eodia.iabns
# rcph.abql
# yab.eyb
# qfc.hab
# nij.abxv
# uxabz.ndy
# abkq.bci
# isrm.abuny
# feujg.otfab
# abwy.mwf
# abfsu.wsuzl
# vcaum.gabw
# jab.tmaon
# jhqmw.uhab
# skabq.csray
# hairc.vabd
# wuhab.fdsh
# wabe.tbfxv
# tzoj.gab
# fwmep.abnjk
# dqab.dxo
# xtaby.cdoie
# squlz.vabt
# abou.rcgk
# pjabr.cgbax
# urj.abdyx
# zabg.gsi
# gzwab.gvzy
# gab.wohvc
# gduz.abig
# eab.kvur
# qldje.abocf
# abxtl.qopfn
# flky.abd
# abqy.irylt
# loabj.ucpsm
# mqjo.zvxab
# ztr.texab
# qtm.abq
# dkfzr.kzxab
# inat.nab
# jluh.lfab
# wjxzg.kabw
# abyhf.lfg
# cuo.xyabf
# mhab.uphsr
# usofr.njabi
# itws.isabm
# zabo.xkt
# cabme.plvme
# ioup.abgvo
# pln.lpab
# ugkf.abmcs
# lxab.oha
# labfq.jbw
# svqbh.abve
# zgp.uqfab
# wamzh.abph
# abs.yro
# qiyn.pgeab
# abkvn.qdm
# vaow.zabp
# obyg.oabsk
# vhnu.abd
# wuq.yabm
# abdk.ulxg
# dsuab.fhsnu
# abr.oxv
# qop.mnyab
# spme.abev
# fipab.zqre
# hictk.xabzd
# nzabt.nhu
# abp.njazm
# efabn.iaovf
# uabx.hugn
# mabs.tdyri
# uchil.yab
# iabhx.nchf
# tosjq.zcabv
# bclr.mabwz
# cgk.zab
# cab.trfv
# qgxab.quze
# rowta.fabqk
# hzoy.eabr
# gabtl.dxv
# hsvxi.abd
# habgr.cup
# qov.abd
# mabu.avyp
# abqh.vqmxg
# ogxfn.hqabr
# gdab.sbxra
# uaszj.xabwt
# abh.kohs
# abzwi.nuq
# qeb.wabjo
# vuf.hqgab
# xutab.xbjc
# abwxu.agtk
# abfe.rbo
# osiab.eih
# ojabg.zwi
# qabig.krie
# mjyq.aby
# vabsh.bwa
# wasiy.jgab
# gmkql.qvabt
# srctx.mabus
# kpzu.abjme
# ukdm.ywabm
# vnlh.abt
# hry.oabc
# aboi.vlc
# ynz.habw
# hab.lhxjy
# fmvna.zabd
# azklm.xab
# lwp.sabe
# joab.qpt
# kycag.abhzk
# qgox.rab
# rabdl.lpia
# rsfpn.uab
# abv.yujgc
# meczl.iabo
# labi.gtl
# tqabg.ufwmo
# kab.fgshq
# oqab.nkcmq
# urab.rxza
# cyab.wij
# abkuc.thqsb
# xnib.abhtw
# bgylp.abj
# edv.sabq
# juab.oie
# jop.oabl
# jhsir.gabz
# abw.wzs
# fsjab.ojx
# lsab.wnjox
# vnm.pnsab
# abwe.zlm
# tfk.dabv
# absr.fva
# abpw.dpwze
# paur.abvz
# ermux.koabj
# yvab.bnaxm
# ouctp.xabcw
# qiko.fabc
# xkab.udgvw
# cer.jlab
# qdt.abolr
# req.pabnl
# rabkd.dmor
# sab.eop
# qwc.abdwo
# ucpof.abgh
# cabhw.rhb
# ujpzr.gscab
# dpm.abokn
# gabql.zta
# aoex.abt
# hydn.abfmy
# vqwab.tuw
# aby.flom
# jpm.abk
# vcgab.xhmvy
# abq.kopqy
# abdvx.gzx
# abzn.jipb
# msnbi.snwab
# rcns.abj
# igq.glzab
# duahq.rzabm
# pabgu.afqmh
# tpab.vjpm
# quab.bru
# cab.xdq
# gzrb.abyjc
# mcg.luabs
# ucvqk.pluab
# sabe.izmav
# abvex.ameo
# abfqt.dig
# pusc.ablwi
# hmjrg.oabfw
# iep.abe
# kaet.kabzo
# rab.mylnv
# yahk.rabs
# voy.qnuab
# pvrx.abvms
# bryvj.cabm
# qyi.fabn
# jlu.fabn
# rnabo.qazco
# rab.jpv
# abuj.fem
# wghab.gmf
# abnpu.tivrk
# oicab.lavzs
# abr.ktegf
# abuw.kyj
# rtabc.afgsy
# kab.npo
# kzy.abfei
# rgay.abpt
# pzab.oiybu
# owab.aro
# abq.iyevs
# eitlx.rabw
# wabs.ekb
# abstn.wed
# utcmo.eabu
# tlab.zojdw
# gtqz.oabl
# abdy.dne
# lwrv.aby
# mpivc.abev
# zhuso.fab
# puxb.cnlab
# knio.abq
# rupty.tabqu
# vxhq.mabjh
# vabf.dpz
# zgbul.abz
# dab.hlpx
# xqabf.ptwoy
# cab.keda
# dabt.wnqf
# swyab.jph
# anrki.nab
# aberq.toze
# xptab.lptiv
# xcs.lsjab
# ablq.ctdkv
# abjv.dztl
# mudab.pdx
# keq.abgeh
# dabt.blhg
# hsplm.abd
# afqto.raboq
# gbvtl.abuto
# jabfm.mspa
# vymxu.pmabf
# abdus.gcor
# moib.iab
# qabmc.giewv
# xpbg.kab
# mrdax.vabq
# cvhab.qjtm
# heg.erab
# abpx.tkb
# rwhl.efab
# vabsl.gam
# dln.nzabr
# abovj.dszkc
# muakd.abigo
# abmhc.hkl
# gabm.pfhr
# sabif.xdkw
# aboh.qwhxs
# abt.jlcfp
# fcabp.niaph
# heab.edcx
# jabv.yaw
# abzk.bktjl
# tzqcf.gwzab
# ovrab.myzv
# lvab.pgf
# jab.jkg
# kfq.abdwf
# abi.myr
# hzcu.habn
# msfpx.jkab
# abc.pbo
# iabp.cysab
# tia.abkin
# iab.apnsg
# dnkep.lkabo
# exto.tyabc
# abrx.rwzn
# rab.xnu
# abw.diel
# uabm.lwqyn
# tgab.xznjq
# xsev.abzx
# tab.gzv
# blaq.dabnj
# abd.aqdwx
# abxzt.xuiwt
# absol.aqwf
# frzab.coxkd
# wto.abv
# ogn.nab
# niwd.viabr
# abxg.nicz
# uyabx.mtour
# jmaf.abjlq
# eqnab.fpsl
# abvh.ohr
# dgkz.ynabv
# yabne.ytho
# evl.lkab
# tqeu.habre
# oabf.ruj
# rvab.roadp
# rja.abnlu
# zabi.khp
# ezab.ect
# fptki.fhab
# abvc.csmiv
# lxab.dot
# gzwad.wabnd
# zab.sxh
# zhp.dab
# nabx.gvre
# gnh.nrabc
# vfos.abs
# abu.fqib
# mqrwf.mlabu
# sqby.pabk
# jxab.imeur
# osx.kabuh
# habpz.cqsmo
# dabk.apm
# ypa.jrab
# abh.ymr
# mpkwx.hab
# iabhg.awy
# zjabh.ajbdk
# rdt.epabl
# dabk.kwqb
# abwu.gyevq
# absqm.oci
# abjyc.kpdm
# ndxab.ergm
# bqma.pab
# twab.ktc
# kcsyf.tab
# tnvia.mabe
# qlpjc.onabx
# tld.abyq
# abv.spjz
# pky.uab
# oai.vkwab
# dabsm.xek
# ehb.jabl
# gkab.ochz
# absiv.ngj
# vsx.abv
# abxu.btsi
# abfjk.kxoi
# fyci.uab
# suab.ndxrt
# abnz.qrge
# abr.rdi
# xtabe.htz
# ejnwv.yabc
# luabq.nws
# jab.bgrc
# absx.coyh
# abt.kgxa
# habi.rydfx
# xab.jkyod
# meab.ozj
# rjabk.vqc
# asn.mabln
# lqab.zpu
# vrapj.absu
# aekwp.wab
# abov.tsro
# diab.xodf
# uqeid.abw
# wjsh.iabg
# vis.gpab
# wcx.abdl
# tfab.amgu
# rvy.abm
# bzvlc.abfur
# qabwp.ips
# cabrn.meihj
# abhsl.dih
# dab.fal
# qipwk.rgdab
# abqz.prxus
# abw.zion
# jly.ovcab
# pabio.vspif
# cna.qablp
# giv.ecab
# abc.lup
# dxhk.abz
# dqw.abc
# abx.izyn
# vhiu.abm
# mzf.qkab
# vabrd.otvnl
# rshlw.fyabk
# abq.afk
# meabs.mdkpt
# dsab.ewtop
# bhxl.edabp
# rmayd.abvtd
# ofqym.abfk
# abigf.tmwa
# hfxcp.abnh
# osyr.abnkf
# umab.tdkw
# dabp.lpufo
# wxe.pouab
# abczo.xobg
# abn.scbya
# wkco.mzab
# gjvr.jgab
# lsp.wabq
# abkof.botli
# gwab.jxda
# oabpm.xno
# igbyu.abjlw
# ofnjz.abwl
# fabs.ojm
# vtab.nmgcd
# abqe.bquyw
# daon.yabl
# ablug.vrayq
# sphdw.yabkd
# doab.zbftc
# hoabw.ymc
# cabys.mtv
# abu.sedu
# abwm.ktal
# wlabo.tqi
# abfu.luet
# abex.lvuz
# miy.abwq
# nltq.abcj
# kab.osab
# erg.vwab
# gabr.lft
# ysabt.icq
# absjm.tqbs
# jic.hmab
# rseal.dab
# abw.ykb
# cjabi.zbr
# oabh.spc
# agk.abq
# lhauf.guab
# lsab.uvm
# ulab.ukci
# lteih.abdf
# jabp.mruz
# wkgvi.abpoi
# oabrj.shuo
# cab.trzlu
# abdrq.yzuno
# weabi.yrxck
# dgoab.qcp
# obsw.roabw
# iwyz.xiab
# abgny.ozugn
# abx.kdia
# eab.vwjb
# abfk.kzjsc
# sdxgm.veab
# tpcnl.froab
# abrq.tkz
# rbcqx.toab
# ftab.lifau
# vqf.qtabu
# fnxab.maein
# abcw.aljnv
# bosw.abuyn
# uhy.tfab
# abcvz.bethf
# abfw.slg
# yzgb.lyvab
# lxrp.abe
# kabxl.lcusk
# jabz.vdg
# glp.nab
# udoiz.abytm
# abnmy.bemkx
# oabh.ypmau
# dab.plb
# aby.ekt
# wabpf.ofnb
# abgi.nqflr
# msab.iyfn
# otmsj.abuj
# coab.aydgq
# abjzm.sovyj
# rfs.wabn
# witr.foab
# vab.ctlm
# ietab.oxmhn
# wikh.fabn
# fhtab.tybis
# ayvco.fabzx
# gut.abdwr
# dan.abrzp
# gxj.abvct
# faboc.qyewa
# zrcpd.oabmc
# vdab.hbzxj
# zab.fswh
# lobaw.abp
# xuvg.dab
# kiabr.spx
# dabs.tfoe
# habl.cmk
# ate.keabt
# abwye.pqd
# gab.cnhme
# urws.xab
# ubosd.abr
# ifau.abzk
# cwv.abmq
# euv.nfabr
# sabn.wgd
# jgrdp.dlgab
# ckhyq.uvabe
# iab.vgp
# fdiab.ncdlf
# fpab.sqkv
# tabfi.macqj
# wmtqj.dfab
# pvejt.habo
# vos.nab
# wub.mabkp
# wkepz.rsuab
# ujfyb.abn
# qcsgd.aboju
# abl.ljxd
# pmy.jabu
# abve.ghxe
# jzuf.miab
# zcd.iabx
# ied.wzab
# pklh.zabw
# abyed.lpv
# soabt.gcj
# vuyab.zrul
# abn.xhwm
# cnp.wduab
# ghbx.drab
# abjs.pcy
# kimab.ohgrf
# oyi.abt
# ogvx.pabxl
# abq.ajinr
# ztca.qabgp
# tabkr.fqmc
# kiahx.zgcab
# saby.jgk
# oab.wzvbu
# alw.abtl
# endab.ojr
# umfr.abdy
# cdwts.uabs
# ryvab.tlp
# ygabx.kdawh
# abo.hdbm
# yabx.yxb
# cadiv.gabkz
# ihbq.abuwe
# abxi.gplm
# fqpvi.vphab
# oabey.txon
# xfb.fiabn
# abt.cmnh
# abm.job
# abr.pntk
# hcixt.cabn
# cabs.yiw
# abr.xros
# nsyab.uoyws
# abrow.msw
# ywlc.kabzo
# hvabw.oxaj
# abvj.krbog
# vbfs.jab
# abqxw.iwdk
# dcabw.hos
# abr.iecjt
# abyp.sde
# hfab.fgez
# eagjq.mtab
# fab.krbli
# abvg.tyj
# fabh.giu
# zkabg.bkm
# iuabd.bwcs
# szor.abv
# qoabx.xrdj
# idzms.abs
# qfruc.abedz
# tnab.fhbk
# opqv.yab
# akwx.abery
# abi.zls
# wgum.yablv
# iab.axqr
# zwoqi.cabu
# wab.rhzs
# vfg.oabxz
# sabhx.yaf
# abur.wqlz
# aouz.abiy
# lnrxp.ioab
# ohdab.weuv
# ablzu.qurds
# jeqp.abjf
# fpn.ijabz
# hbydq.aby
# ulvni.abgp
# wabn.sdyx
# ptab.abd
# zts.abmr
# qab.wac
# fxem.abehy
# eabxp.azb
# abixl.wfjn
# fxawq.qabo
# zxty.abyj
# abhi.kqn
# sabcl.vzkr
# vabik.ruht
# skc.abjod
# dbz.abri
# efnab.kuxyb
# ycwj.abm
# ahysj.dabc
# xab.bpe
# habyw.cahjd
# rsdyw.xcvab
# pdjq.eabcz
# rabmw.vnh
# hlabg.xtvgs
# udg.kabem
# yabqs.azsok
# igq.tabi
# xzh.vab
# lvk.dabo
# msp.rlab
# sioab.zdvh
# fymgj.gabn
# njtab.riy
# abem.kldi
# abd.mjs
# mkoug.habc
# ardwy.sab
# ofvp.abgr
# pogab.kwt
# xnob.abenf
# abn.uig
# ywbuq.abkeu
# ezabd.nkbdr
# abwf.ylf
# ldy.trjab
# xabt.pko
# eajvg.hgab
# brpd.piab
# myuz.wabep
# chl.irabu
# abj.lnif
# iab.cqt
# exc.abin
# ukabm.wqly
# hdp.nwcab
# xyabq.suhn
# cablo.dae
# eabt.wlmz
# yrn.nabtl
# muxyi.fabti
# hab.hevb
# uqvp.skabl
# mhurw.zxabl
# cwab.sav
# zdpw.gmab
# xmabd.wrap
# wbhqy.rmab
# uro.abfel
# qtrp.abnm
# labf.fli
# kesni.ytabj
# fcsz.abui
# abrgf.cejz
# labrx.ytj
# abud.iqk
# mabj.sir
# erl.iqab
# pwab.out
# rab.ztr
# nabv.vzruf
# abw.ebhcr
# gvh.gab
# mxb.cabo
# tpab.mas
# kgwl.xab
# tjabn.ihkj
# oyab.gyifl
# gjdab.pskti
# jhxu.abqvr
# oenv.fab
# ogab.ozn
# zuvnq.iabn
# mig.mzab
# egabl.zfvx
# tswi.euabm
# jdlhg.vabmg
# iabd.zfnyr
# tkvug.fabn
# ftny.abm
# ckab.sfny
# quhps.abxz
# koq.vlabz
# cainu.abdwn
# zkuv.jabo
# vabfe.lsoz
# xftg.uab
# abpqo.npm
# imnq.abh
# yft.xqgab
# luab.xiho
# sab.dpvx
# xtiok.wabj
# fgnu.abxt
# zabnt.zhlu
# mtabl.ljck
# abk.mcyje
# jab.ymf
# abgs.nvitb
# rzpfx.abz
# abuq.pjmf
# wabpj.ailb
# nhiab.lte
# yrabk.wrzus
# ldjab.doyi
# bctg.abxpd
# abs.sgoce
# zmsic.nab
# ofw.abwhs
# abulf.ngx
# tabv.hof
# smaw.abhp
# rnjz.snabd
# fca.abt
# wpab.ynclk
# gpcem.uabq
# dhqr.abs
# mabto.ocm
# abrvg.jmqfy
# rab.qfteh
# qfnd.lsabf
# ouyhg.abr
# abry.hroxa
# vpyab.com
# iabyp.wpjza
# yrftb.iabcf
# abcoy.zjucf
# jlk.epabi
# zrvab.dfi
# xabc.zxpr
# icwoq.jxab

# %%
import pandas

# %%
df = pandas.DataFrame({"name":name,"age":age})
df
# Out:
#               name  age
# 0        yecv.msvu   29
# 1        wlicq.zxw   47
# 2      qiamc.wzdse   36
# 3        eiv.alpbr   43
# 4        cdsk.rbyk   35
# ...            ...  ...
# 99995     zena.nld   53
# 99996      bzs.hlf   51
# 99997    wkezb.vhl   43
# 99998   uhatk.qcsh   31
# 99999    dul.whbps   29
#
# [100000 rows x 2 columns]

# %%
df[df["name"].str.contains('.*ab.*')]
# Out:
#               name  age
# 17      jzab.lesir   45
# 145      abvue.htu   43
# 355      whts.oabd   27
# 543    qhsuj.zwmab   47
# 795      wruv.qfab   50
# ...            ...  ...
# 99663  abcoy.zjucf   47
# 99732    jlk.epabi   58
# 99802    zrvab.dfi   54
# 99842    xabc.zxpr   26
# 99985   icwoq.jxab   39
#
# [908 rows x 2 columns]

# %%
df[df["age"] > 57]
# Out:
#               name  age
# 44       yriac.zpm   58
# 49      uoqpe.rgoq   58
# 75         kmf.gbm   58
# 92      mwuzr.twdc   58
# 111       upkl.wrd   58
# ...            ...  ...
# 99779     misk.lnh   58
# 99816    sduxn.swn   58
# 99879  lrvgu.qihuy   58
# 99920   gryj.cxymn   58
# 99945  wdxzs.dxhro   58
#
# [2904 rows x 2 columns]
