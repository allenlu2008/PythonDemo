# %%
import pandas,numpy
import time,random
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
cw = pandas.read_csv("data/weather.csv")
dataSet = [(m1,m2)for m1,m2 in zip(cw["max"],cw["min"])]

# %%
cw
# Out:
#        FID city               day  max  min weather    wind   windDesc  \
# 0        0   阿城  2017/5/4 0:00:00   12   -4       晴     西南风  小于3级~3-4级
# 1        1   安达  2017/5/4 0:00:00   12   -3       晴      西风       4-5级
# 2        2   安图  2017/5/4 0:00:00   13   -6    多云转晴  西北风~西风       小于3级
# 3        3   鞍山  2017/5/4 0:00:00   13    0    晴转多云      北风  4-5级~3-4级
# 4        4  阿鲁旗  2017/5/4 0:00:00   10   -4    晴转多云      东风       3-4级
# ...    ...  ...               ...  ...  ...     ...     ...        ...
# 2288  2288   盐边  2017/5/4 0:00:00   34   17    多云转晴      南风       小于3级
# 2289  2289   盐亭  2017/5/4 0:00:00   25   19      阵雨     旋转风       小于3级
# 2290  2290   营山  2017/5/4 0:00:00   27   21    阴转小雨      北风       小于3级
# 2291  2291   仪陇  2017/5/4 0:00:00   25   19   阵雨转小雨      北风       小于3级
# 2292  2292   岳池  2017/5/4 0:00:00   29   21    阴转小雨      南风       小于3级
#
#                x          y
# 0     116.057433  36.172429
# 1     125.384552  46.535467
# 2     128.437652  42.701033
# 3     123.007763  41.118744
# 4     104.269039  25.020963
# ...          ...        ...
# 2288  101.586050  26.940087
# 2289  105.479071  31.247943
# 2290  106.718527  31.162323
# 2291  106.534725  31.443593
# 2292  106.420833  30.540769
#
# [2293 rows x 10 columns]

# %%
clf = KMeans(n_clusters=5)
s = clf.fit(dataSet)
numSamples=len(dataSet)
cw["clf"] = clf.labels_
fig = plt.figure(figsize=(14,10))
ax = fig.gca() 
ax.grid(alpha= 1)
plt.scatter(cw["x"],cw["y"],c=clf.labels_)

# %%
fig = plt.figure(figsize=(16,24))
for i in range(2,10):
    clf = KMeans(n_clusters=i)
    s = clf.fit(dataSet)
    numSamples=len(dataSet)
    cw["clf"] = clf.labels_
    plt.subplot(4,2,i-1)
    plt.scatter(cw["x"],cw["y"],c=clf.labels_)
    plt.title("cluster num :{0}".format(i))
